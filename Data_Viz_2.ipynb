# %% [markdown]
# <a href="https://colab.research.google.com/github/gchn24/DS-Notes/blob/main/Data_Viz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
print("Welcome to Data_Visualisation")
# Out:
# Welcome to Data_Visualisation

# %%
import numpy as np, pandas as pd

# %%
df=pd.read_csv("final_vg.csv")
df
# Out:
#         Rank                                           Name Platform    Year  \
# 0       2061                                           1942      NES  1985.0
# 1       9137                   ¡Shin Chan Flipa en colores!       DS  2007.0
# 2      14279              .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 3       8359                     .hack//G.U. Vol.1//Rebirth      PS2  2006.0
# 4       7109                   .hack//G.U. Vol.2//Reminisce      PS2  2006.0
# ...      ...                                            ...      ...     ...
# 16647   7925                             Zumba Fitness Rush     X360  2012.0
# 16648   6279                     Zumba Fitness: World Party      Wii  2013.0
# 16649   6977                     Zumba Fitness: World Party     XOne  2013.0
# 16650  15422                                         Zwei!!      PSP  2008.0
# 16651  12919  Zyuden Sentai Kyoryuger: Game de Gaburincho!!      3DS  2013.0
#
# ...

# %%
# !pip install seaborn / matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x_val = [0,1,2]
y_val = [3,5,9]

plt.plot(x_val, y_val)

# %%
plt.plot?

# %%
a = np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
x_val = [0,1,2]
y_val = [3,5,9]

plt.plot(x_val, y_val)

plt.show()

# %%
cat_counts = df["Genre"].value_counts()
cat_counts
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
cat_counts.index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='object')

# %%
x = cat_counts.index
y = cat_counts

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.figure(figsize=(12, 5))
x=cat_counts.index
y=cat_counts
plt.bar(x,y)
plt.show()

# %%
plt.figure(figsize=(12, 5))
x=cat_counts.index
y=cat_counts
plt.bar(x,y)
plt.xticks(rotation = 90, fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(12, 5))
x=cat_counts.index
y=cat_counts
plt.barh(x,y)
plt.xticks(rotation = 90, fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(12, 6))
x=cat_counts.index
y=cat_counts
plt.bar(x,y)
plt.xticks(rotation = 45, fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(12, 6))
x=cat_counts.index
y=cat_counts

plt.bar(x,y, 
        width=0.5, 
        color = "purple")


plt.xlabel("Genre", fontsize = 12)
plt.ylabel("Count", fontsize = 12)



plt.xticks(rotation = 45, fontsize = 10)
plt.show()

# %%
plt.figure(figsize=(12, 6))
x=cat_counts.index
y=cat_counts

plt.bar(x,y, 
        width=0.5, 
        color = "purple")


plt.xlabel("Genre", fontsize = 12)
plt.ylabel("Count", fontsize = 12)

plt.title("Count of games per genre", )


plt.xticks(rotation = 45, fontsize = 10)
plt.show()

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
# plt.title

# %%
cat_counts
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data = df,
             x = "Genre")
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data = df, x = "Genre")

plt.xticks(rotation = 45, fontsize = 10)

plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data = df, x = "Genre")

plt.xticks(rotation = 45, fontsize = 10)

plt.title("Count of Games Per Genre")

plt.show()

# %%
df["Genre"].value_counts()
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
df["Genre"].value_counts().index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='object')

# %%
list(df["Genre"].value_counts().index)
# Out:
# ['Action',
#  'Sports',
#  'Misc',
#  'Role-Playing',
#  'Shooter',
#  'Adventure',
#  'Racing',
#  'Platform',
#  'Simulation',
#  'Fighting',
#  'Strategy',
#  'Puzzle']

# %%
list(df["Genre"].value_counts().index)[::-1]
# Out:
# ['Puzzle',
#  'Strategy',
#  'Fighting',
#  'Simulation',
#  'Platform',
#  'Racing',
#  'Adventure',
#  'Shooter',
#  'Role-Playing',
#  'Misc',
#  'Sports',
#  'Action']

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data = df, 
              x = "Genre",
             order = df["Genre"].value_counts().index)

plt.xticks(rotation = 45, fontsize = 10)

plt.title("Count of Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data = df, 
              x = "Genre",
             order = list(df["Genre"].value_counts().index)[::-1])

plt.xticks(rotation = 45, fontsize = 10)

plt.title("Count of Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data = df, 
              x = "Genre",
             order = list(df["Genre"].value_counts().index)[::-1],
             palette = "flare")

plt.xticks(rotation = 45, fontsize = 10)

plt.title("Count of Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(12, 6))

ax = sns.countplot(data = df, 
              x = "Genre",
             order = list(df["Genre"].value_counts().index)[::-1],
             palette= "viridis")

plt.xticks(rotation = 45, fontsize = 10)


for i in ax.containers:
    ax.bar_label(i, fontsize = 10)


plt.title("Count of Games Per Genre")

plt.show()

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
# df["Year"].astype(int)

# %%
df["Year"].min()
# Out:
# 1980.0

# %%
df["Year"].max()
# Out:
# 2020.0

# %%
df["Year"].unique()
# Out:
# array([1985., 2007., 2012., 2006., 2002., 2010., 2003., 2009., 2000.,
#        2008., 1999., 2013., 2011., 1998., 2014., 2016., 2001., 2005.,
#        2004., 1996., 1995., 2015., 1984., 1997., 1994., 1982.,   nan,
#        1986., 1989., 1981., 1980., 1983., 1992., 2017., 2019., 1991.,
#        1993., 1987., 1990., 1988., 2018., 2020.])

# %%
df["Year"].nunique()
# Out:
# 41

# %%
plt.hist(df["Year"])
plt.show()

# %%
plt.hist(df["Year"],bins=4)
# plt.show()
# Out:
# (array([ 215., 1782., 9222., 5162.]),
#  array([1980., 1990., 2000., 2010., 2020.]),
#  <BarContainer object of 4 artists>)

# %%
counts,bins,_ =  plt.hist(df["Year"],bins=4)

# %%
counts
# Out:
# array([ 215., 1782., 9222., 5162.])

# %%
bins
# Out:
# array([1980., 1990., 2000., 2010., 2020.])

# %%
# n

# %%
plt.hist(df["Year"],bins=4)
plt.show()

# %%
my_bins = [1980, 1983, 1990, 2005, 2015, 2020]

# %%
plt.hist(df["Year"], bins = my_bins)
# Out:
# (array([   94.,   121.,  4987., 10209.,   970.]),
#  array([1980., 1983., 1990., 2005., 2015., 2020.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df["Year"])
plt.show()

# %%
sns.histplot(df["Year"], bins = 10)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.histplot(df["Year"], bins = 10)

plt.title("histogram of year")

plt.show()

# %%
sns.histplot(df["Year"], bins = 10, kde = True)

plt.title("histogram of year")

plt.show()

# %%
sns.displot(data=df,
             x="Year", kind="kde")

plt.show()

# %%
sns.kdeplot(data = df, x = "Year", shade = True)
plt.show()
# Out:
# <ipython-input-56-ecaf4449a652>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = df, x = "Year", shade = True)

# %%
sns.kdeplot(x = df["Year"], shade = True)
plt.show()
# Out:
# <ipython-input-57-dbafa9072954>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = df["Year"], shade = True)

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
sns.boxplot(x=df["Global_Sales"])
plt.show()

# %%
sns.boxplot(y=df["Global_Sales"])
plt.show()

# %% [markdown]
# # bivariate Analysis

# %%
df.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
df["Name"].nunique()
# Out:
# 11493

# %%
df["Name"].value_counts()
# Out:
# Ice Hockey                                       41
# Baseball                                         17
# Need for Speed: Most Wanted                      12
# Ratatouille                                       9
# FIFA 14                                           9
#                                                  ..
# Indy 500                                          1
# Indy Racing 2000                                  1
# Indycar Series 2005                               1
# inFAMOUS                                          1
# Zyuden Sentai Kyoryuger: Game de Gaburincho!!     1
# Name: Name, Length: 11493, dtype: int64

# %%
df["Name"] == "Ice Hockey"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16647    False
# 16648    False
# 16649    False
# 16650    False
# 16651    False
# Name: Name, Length: 16652, dtype: bool

# %%
df[df["Name"] == "Ice Hockey"].head()
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 6073  3.860566  4.751539     2.004268     15.855389
# 6074  1.493442  2.741701     0.394830      4.956249
# 6075  0.020000  0.000000     0.010000      0.470000
# 6076  0.020000  0.000000     0.010000      0.470000
# 6077  0.020000  0.000000     0.010000      0.470000

# %%
ih = df[df["Name"] == "Ice Hockey"]

# %%
ih.shape
# Out:
# (41, 11)

# %%
sns.barplot(data=ih,
            x="Year",
            y="NA_Sales")
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(data=ih,
            x="Year",
            y="NA_Sales")
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(data=ih,
            x="Year",
            y="NA_Sales")



plt.xticks(rotation=45,fontsize=8)
plt.show()

# %%
plt.figure(figsize=(14,6))

ax = sns.barplot(data=ih,
            x="Year",
            y="NA_Sales")

for i in ax.containers:
    ax.bar_label(i,fontsize=7)


plt.xticks(rotation=45,fontsize=8)
plt.show()

# %%
plt.figure(figsize=(14,6))
plot = sns.lineplot(data=ih,
            x="Year",
            y="NA_Sales")

plt.show()

# %%
plt.figure(figsize=(14,6))
plot = sns.lineplot(data=ih,
            x="Year",
            y="NA_Sales",
                   color = "green")
plt.title("Ice hockey Sales Trend")

plt.show()

# %%
# plt.figure(figsize=(14,6))
plot = sns.lineplot(data=ih,
            x="Year",
            y="NA_Sales",
            color = "green")

plt.xlim(left = 1995, right = 2010)

plt.title("Ice hockey Sales Trend")


plt.show()

# %%
plot = sns.lineplot(data=ih,
            x="Year",
            y="NA_Sales",
            color = "green")

plt.ylim(bottom = 0.7, top = 0.8)

plt.title("Ice hockey Sales Trend")


plt.show()

# %%
a = [4, 3, 4, 4, 2, 2, 2, 3, 2, 3, 1, 6, 1, 3, 1, 2, 2, 1, 1, 3, 3, 2, 2, 2, 2, 1, 3, 3, 3, 1, 2, 1, 3, 3, 3, 1, 3, 1, 2, 3, 2, 4, 2, 4, 4, 4, 3, 2, 2, 3, 3, 3, 3, 3, 1, 2, 4, 5, 3, 3, 2, 1, 2, 2, 3, 3, 2, 6, 2, 2, 3, 3, 2, 1, 3, 3, 2]

# %%
a[:5]
# Out:
# [4, 3, 4, 4, 2]

# %%
a = pd.Series(a)
a
# Out:
# 0     4
# 1     3
# 2     4
# 3     4
# 4     2
#      ..
# 72    2
# 73    1
# 74    3
# 75    3
# 76    2
# Length: 77, dtype: int64

# %%
a.value_counts()
# Out:
# 3    28
# 2    25
# 1    13
# 4     8
# 6     2
# 5     1
# dtype: int64

# %%
a.value_counts().index
# Out:
# Int64Index([3, 2, 1, 4, 6, 5], dtype='int64')

# %%
plt.bar(a.value_counts().index , a.value_counts())
# Out:
# <BarContainer object of 6 artists>

# %%
sns.countplot(pd.Series(a))
# Out:
# <Axes: ylabel='count'>
