# %% [markdown]
# <a href="https://colab.research.google.com/github/gchn24/DS-Notes/blob/main/MEDIUM_TSHIRT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# !gdown '1cB3Zy5EsX-tgR_HZpY6ajUW9GoNEmyQs' -O 'medium_tshirt.csv'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cB3Zy5EsX-tgR_HZpY6ajUW9GoNEmyQs
# To: /content/medium_tshirt.csv
# 100% 9.80k/9.80k [00:00<00:00, 30.3MB/s]

# %%
import numpy as np, pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # 1. Height - Weight Data

# %%
df = pd.read_csv("medium_tshirt.csv")

# %%
df.shape
# Out:
# (200, 4)

# %%
df.head()
# Out:
#    Gender     Height      Weight     T-Shirt
# 0  Female  64.723877  138.085796  Not Medium
# 1    Male  67.272171  187.363366      Medium
# 2    Male  74.520972  216.533191  Not Medium
# 3  Female  65.880014  131.761443  Not Medium
# 4    Male  64.846301  157.718438      Medium

# %%
df["H/W"] = df.Height/df.Weight

# %%
df
# Out:
#      Gender     Height      Weight     T-Shirt       H/W
# 0    Female  64.723877  138.085796  Not Medium  0.468722
# 1      Male  67.272171  187.363366      Medium  0.359047
# 2      Male  74.520972  216.533191  Not Medium  0.344155
# 3    Female  65.880014  131.761443  Not Medium  0.499995
# 4      Male  64.846301  157.718438      Medium  0.411152
# ..      ...        ...         ...         ...       ...
# 195    Male  68.746986  195.116244  Not Medium  0.352339
# 196    Male  69.744829  188.181125  Not Medium  0.370626
# 197  Female  60.050846  115.656208  Not Medium  0.519219
# 198  Female  64.694073  135.549114  Not Medium  0.477274
# 199  Female  63.624719  144.046264      Medium  0.441696
#
# [200 rows x 5 columns]

# %%
sns.histplot(data = df, x = "H/W", hue = "T-Shirt")
# Out:
# <Axes: xlabel='H/W', ylabel='Count'>

# %%
pd.crosstab(df["Gender"],
            df["T-Shirt"])
# Out:
# T-Shirt  Medium  Not Medium
# Gender
# Female       48          51
# Male         48          53

# %%
df[["Height", "Weight"]].mean()
# Out:
# Height     66.657306
# Weight    163.563169
# dtype: float64

# %%
sns.scatterplot(data = df, x = "Height", y = "Weight", hue = "T-Shirt")

plt.axhline(y = df.Weight.mean(), linestyle = '--', color = 'black', alpha = 0.4)

plt.axvline(x = df.Height.mean(), linestyle = '--', color = 'black', alpha = 0.4)

# %%
from sklearn.preprocessing import StandardScaler

# %%
z_h = (df.Height - df.Height.mean())/(df.Height.std())
z_h
# Out:
# 0     -0.476284
# 1      0.151467
# 2      1.937148
# 3     -0.191479
# 4     -0.446126
#          ...
# 195    0.514775
# 196    0.760585
# 197   -1.627446
# 198   -0.483626
# 199   -0.747052
# Name: Height, Length: 200, dtype: float64

# %%
df[["Height", "Weight"]].head(3)
# Out:
#       Height      Weight
# 0  64.723877  138.085796
# 1  67.272171  187.363366
# 2  74.520972  216.533191

# %%
SCALER = StandardScaler()

# %%
SCALER.fit_transform(df[["Height", "Weight"]])
# Out:
# array([[-4.77479262e-01, -7.65628544e-01],
#        [ 1.51846752e-01,  7.15227214e-01],
#        [ 1.94200886e+00,  1.59181882e+00],
#        [-1.91959894e-01, -9.55683675e-01],
#        [-4.47245295e-01, -1.75641830e-01],
#        [-1.97230772e+00, -1.95475058e+00],
#        [-4.58133467e-01, -4.18651483e-01],
#        [-7.91976300e-01, -9.02972191e-01],
#        [ 4.60561338e-01,  7.35961637e-01],
#        [ 9.59412696e-01,  1.40146338e+00],
#        [ 1.24916971e+00,  1.70423206e+00],
#        [ 1.40279626e+00,  1.59723666e+00],
#        [ 1.35038215e-01,  1.62845757e-01],
#        [-1.84916100e+00, -1.54822042e+00],
#        [ 5.59676855e-01,  6.89068514e-01],
#        [ 6.95386792e-01,  7.07942156e-01],
#        [-7.80393403e-01, -5.20901462e-01],
#        [ 3.46776175e-01,  1.48952178e-01],
#        [-5.17745605e-01, -5.02878582e-02],
#        [-4.41406924e-01, -5.81077696e-01],
#        [ 1.40916414e+00,  1.57749371e+00],
#        [-6.91538695e-01, -1.14680172e+00],
#        [-5.75560112e-02,  1.75573308e-01],
#        [-5.07297442e-01, -4.48496711e-01],
#        [ 9.26494698e-02,  4.85754148e-01],
#        [ 1.36977964e+00,  9.40737600e-01],
#        [ 8.12694250e-01,  9.89006345e-01],
#        [ 8.42091897e-02,  7.91256338e-01],
#        [ 9.94542820e-02,  7.26115182e-01],
#        [ 2.14201524e+00,  2.31027437e+00],
#        [-1.97589077e+00, -1.60925680e+00],
#        [-3.64397749e-01, -6.43805704e-01],
#        [ 1.43074028e+00,  1.15266008e+00],
#        [ 1.71370953e+00,  1.98313037e+00],
#        [-6.69985334e-01, -9.65702314e-01],
#        [-1.04176006e-01, -4.25217124e-01],
#        [-1.13204281e+00, -1.81576269e+00],
#        [-6.37179860e-01, -1.03524813e+00],
#        [ 1.06660892e+00,  8.41706818e-01],
#        [-1.05518714e+00, -8.64746649e-01],
#        [ 5.37544015e-02, -5.26054166e-01],
#        [-1.89752716e-01, -1.36953237e-01],
#        [ 4.20450024e-01,  3.19599353e-01],
#        [ 1.29654965e-02, -3.00409813e-01],
#        [-1.98459365e+00, -1.73938851e+00],
#        [-1.20615158e+00, -1.54150828e+00],
#        [-2.69620010e+00, -1.66608096e+00],
#        [-7.10467539e-01, -1.12987539e+00],
#        [-6.49589685e-01, -7.41869666e-01],
#        [ 1.86941396e-01,  6.09322040e-01],
#        [-4.91959571e-01, -5.28413043e-01],
#        [-1.14626243e+00, -8.98845006e-01],
#        [-1.64347824e+00, -1.47604389e+00],
#        [-8.22376579e-01, -5.79683441e-01],
#        [-1.10282559e+00, -1.52142918e+00],
#        [ 6.87178862e-01,  1.78304732e-01],
#        [-9.31971718e-01, -4.19414581e-01],
#        [ 3.69261139e-01,  8.89404122e-01],
#        [ 4.87372640e-01,  8.88487063e-01],
#        [-1.91675824e+00, -1.85959205e+00],
#        [ 1.23297387e+00,  1.11532435e+00],
#        [ 2.62243285e-01, -3.52110853e-01],
#        [ 1.04323532e+00,  8.14851937e-01],
#        [-3.51802904e-01,  1.55567573e-01],
#        [ 7.27590764e-01,  9.06459651e-01],
#        [ 2.63661558e-01,  4.95506735e-01],
#        [-6.30025249e-01, -5.64881353e-01],
#        [ 1.09804656e+00,  9.97606507e-01],
#        [-6.93573080e-01, -1.27619542e+00],
#        [-5.37090903e-01, -7.07778887e-01],
#        [-1.01796347e+00, -1.16386296e+00],
#        [ 5.74983442e-01,  6.84530884e-01],
#        [ 7.28316638e-01,  6.33511406e-01],
#        [-1.25573480e-01, -3.24957535e-01],
#        [ 4.02626063e-01,  4.46845891e-01],
#        [-3.53798127e-01, -8.19527690e-02],
#        [-1.29456283e+00, -1.72098372e+00],
#        [ 2.56792973e-01,  1.13206258e-02],
#        [-1.16507735e-01, -2.77745309e-01],
#        [-1.78811471e-01, -4.77918978e-01],
#        [ 1.78863861e+00,  1.56256422e+00],
#        [-1.35317218e+00, -1.26925052e+00],
#        [ 2.26873217e-01,  3.70496374e-01],
#        [ 1.41078896e+00,  1.83435154e+00],
#        [ 9.11354399e-01,  8.19028890e-01],
#        [-8.49281196e-01, -6.43226936e-01],
#        [ 1.39580622e+00,  1.19249211e+00],
#        [ 8.22844907e-01,  6.69627294e-01],
#        [ 2.30725860e+00,  1.82944262e+00],
#        [ 4.81766324e-01,  2.72410041e-01],
#        [-7.88958927e-01, -1.10809184e+00],
#        [ 5.58001140e-01,  2.13218563e-01],
#        [ 1.15394200e+00,  9.93395823e-01],
#        [ 4.49638564e-01,  8.15077416e-01],
#        [-1.75549148e+00, -1.34337928e+00],
#        [ 1.55150733e+00,  1.06778339e+00],
#        [ 1.23070482e-01,  3.80332739e-01],
#        [-1.08862120e+00, -1.41113065e+00],
#        [ 6.55943608e-01, -2.72824678e-01],
#        [ 7.45204030e-01,  9.28357981e-01],
#        [-8.20019057e-01, -7.68957631e-01],
#        [-1.06506290e+00, -1.04671069e+00],
#        [-8.29118092e-01, -1.25058401e+00],
#        [ 6.84387461e-01,  1.80652038e-01],
#        [-7.22373722e-01, -2.67693992e-01],
#        [ 4.13571481e-01,  1.23565783e+00],
#        [-7.20358675e-01, -5.02567773e-01],
#        [-1.38230832e-01,  2.35383916e-03],
#        [-1.64856521e+00, -1.52240650e+00],
#        [ 1.70201096e+00,  1.76504364e+00],
#        [-5.40319115e-01, -8.52531664e-01],
#        [ 5.14674621e-01,  5.96155153e-01],
#        [-1.79199994e+00, -1.63897126e+00],
#        [ 1.83180584e-01, -6.53860369e-02],
#        [ 3.62385084e-01,  7.01532703e-01],
#        [ 5.98975343e-01,  5.96288927e-01],
#        [ 1.20884283e+00,  6.63986867e-01],
#        [-2.70160929e-01, -6.69284385e-01],
#        [-1.19095275e+00, -6.05284776e-01],
#        [ 1.55905097e+00,  1.11032268e+00],
#        [ 1.22471522e+00,  1.34558196e+00],
#        [-5.80131832e-01, -6.81675181e-01],
#        [ 2.47790918e+00,  2.09143699e+00],
#        [-1.13304452e+00, -9.28840088e-01],
#        [ 1.03224157e+00,  8.59389956e-01],
#        [ 1.38845963e+00,  1.06001042e+00],
#        [-1.58928444e+00, -1.67782133e+00],
#        [-3.90983429e-01, -4.30720551e-01],
#        [ 5.61350153e-01,  7.28388821e-01],
#        [ 7.40301096e-01,  7.82737258e-01],
#        [-1.48006380e+00, -1.57461018e+00],
#        [ 4.63658111e-01,  6.95385492e-01],
#        [ 5.83959723e-01,  1.05359371e+00],
#        [-1.64444987e+00, -2.00462346e+00],
#        [ 5.36423339e-01, -1.73121405e-02],
#        [ 1.24464520e+00,  1.47088842e+00],
#        [ 2.14119354e-01,  6.53201632e-01],
#        [-3.84085169e-01, -2.07495586e-01],
#        [-1.15097321e+00, -4.31873575e-01],
#        [-3.54366659e-01, -3.03900780e-01],
#        [ 4.03863233e-01,  3.73957584e-01],
#        [ 1.38566119e-01,  1.16804235e-01],
#        [ 2.52532535e-01,  3.44076465e-01],
#        [ 1.91150611e+00,  1.47470814e+00],
#        [-1.36166359e+00, -1.08531611e+00],
#        [-3.91484134e-01, -5.37894069e-01],
#        [-1.18335546e+00, -8.16585918e-01],
#        [ 3.65781176e-01,  1.63139381e-01],
#        [ 2.75164706e-01, -4.19029272e-01],
#        [-5.07017980e-01,  5.41722061e-02],
#        [ 8.64598982e-01,  1.11102744e+00],
#        [ 1.79254801e-01,  1.05141757e+00],
#        [-4.44899719e-01, -1.56919743e-01],
#        [ 9.99866217e-01,  1.19085673e+00],
#        [ 8.99642892e-01,  9.92351179e-01],
#        [ 9.97677022e-01,  9.16133578e-01],
#        [-8.61825889e-01, -1.17418571e+00],
#        [-2.03498352e+00, -2.01767526e+00],
#        [ 2.57918182e-01, -1.28519200e-01],
#        [ 1.54697084e+00,  1.51342381e+00],
#        [ 4.12321399e-03, -3.76141071e-02],
#        [-3.59877978e-01, -4.65346710e-01],
#        [-4.27189529e-02, -7.51127441e-02],
#        [-1.49941257e+00, -1.53152543e+00],
#        [ 5.67121603e-01,  4.42494093e-01],
#        [ 2.20229614e-01,  5.92112004e-01],
#        [ 1.92768877e+00,  1.69037857e+00],
#        [-6.14790347e-01, -6.05531452e-01],
#        [-1.17655062e+00, -1.05197543e+00],
#        [ 2.53919974e-01,  4.50582023e-01],
#        [-9.05813570e-02, -7.09925499e-01],
#        [-9.47679128e-01, -1.83802241e+00],
#        [-1.01139579e+00, -6.69737533e-01],
#        [-2.14677674e-01,  8.15538278e-02],
#        [-4.67212373e-01, -3.90742023e-01],
#        [ 4.57025028e-02, -1.05816527e-01],
#        [-1.20255938e+00, -1.27629050e+00],
#        [ 9.57530086e-01,  1.22776336e+00],
#        [-1.37642502e+00, -1.34688081e+00],
#        [ 1.78220619e+00,  1.62463130e+00],
#        [ 1.35544978e+00,  8.50782788e-01],
#        [ 3.55487011e-01,  7.72414353e-01],
#        [ 3.87034727e-02,  6.84018141e-01],
#        [-4.31138668e-01, -1.31266041e-01],
#        [ 5.25176325e-01,  7.23404115e-01],
#        [ 2.53454953e-01, -3.69123759e-01],
#        [ 6.59949675e-01,  5.04732102e-01],
#        [ 1.42581634e-01, -3.04620041e-01],
#        [ 9.37034094e-01,  5.79781341e-01],
#        [ 1.08667339e+00,  7.68437472e-01],
#        [ 1.02000139e+00,  1.29292162e+00],
#        [-1.63401576e+00, -1.13838962e+00],
#        [-1.18611233e+00, -1.34560489e+00],
#        [ 1.18405574e-01,  5.82967680e-01],
#        [ 2.67965068e-01, -3.76994696e-02],
#        [ 5.16066644e-01,  9.48211381e-01],
#        [ 7.62493893e-01,  7.39801947e-01],
#        [-1.63152961e+00, -1.43966716e+00],
#        [-4.84839521e-01, -8.41859164e-01],
#        [-7.48926883e-01, -5.86508640e-01]])

# %%
df_std = pd.DataFrame(SCALER.fit_transform(df[["Height", "Weight"]]),  columns = ["Height", "Weight"])

# %%
df_std
# Out:
#        Height    Weight
# 0   -0.477479 -0.765629
# 1    0.151847  0.715227
# 2    1.942009  1.591819
# 3   -0.191960 -0.955684
# 4   -0.447245 -0.175642
# ..        ...       ...
# 195  0.516067  0.948211
# 196  0.762494  0.739802
# 197 -1.631530 -1.439667
# 198 -0.484840 -0.841859
# 199 -0.748927 -0.586509
#
# [200 rows x 2 columns]

# %%
df_std["T-Shirt"] = df["T-Shirt"].copy()

# %%
df_std
# Out:
#        Height    Weight     T-Shirt
# 0   -0.477479 -0.765629  Not Medium
# 1    0.151847  0.715227      Medium
# 2    1.942009  1.591819  Not Medium
# 3   -0.191960 -0.955684  Not Medium
# 4   -0.447245 -0.175642      Medium
# ..        ...       ...         ...
# 195  0.516067  0.948211  Not Medium
# 196  0.762494  0.739802  Not Medium
# 197 -1.631530 -1.439667  Not Medium
# 198 -0.484840 -0.841859  Not Medium
# 199 -0.748927 -0.586509      Medium
#
# [200 rows x 3 columns]

# %%
sns.scatterplot(data = df_std, x = "Height",
                y = "Weight", hue = "T-Shirt")
plt.axhline(y = df_std.Weight.mean(), linestyle = '--',
            color = 'black', alpha = 0.4)
plt.axvline(x = df_std.Height.mean(), linestyle = '--',
            color = 'black', alpha = 0.4)

# %%
df_std["Hsq"] = df_std["Height"]**2
df_std["Wsq"] = df_std["Weight"]**2

# %%
df_std
# Out:
#        Height    Weight     T-Shirt       Hsq       Wsq
# 0   -0.477479 -0.765629  Not Medium  0.227986  0.586187
# 1    0.151847  0.715227      Medium  0.023057  0.511550
# 2    1.942009  1.591819  Not Medium  3.771398  2.533887
# 3   -0.191960 -0.955684  Not Medium  0.036849  0.913331
# 4   -0.447245 -0.175642      Medium  0.200028  0.030850
# ..        ...       ...         ...       ...       ...
# 195  0.516067  0.948211  Not Medium  0.266325  0.899105
# 196  0.762494  0.739802  Not Medium  0.581397  0.547307
# 197 -1.631530 -1.439667  Not Medium  2.661889  2.072642
# 198 -0.484840 -0.841859  Not Medium  0.235069  0.708727
# 199 -0.748927 -0.586509      Medium  0.560891  0.343992
#
# [200 rows x 5 columns]

# %%
sns.scatterplot(data = df_std, x = "Hsq", y = "Wsq",
                hue = "T-Shirt", size = 0.05,
                legend = False)
# Out:
# <Axes: xlabel='Hsq', ylabel='Wsq'>
