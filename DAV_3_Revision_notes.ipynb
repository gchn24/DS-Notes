# %% [markdown]
# <a href="https://colab.research.google.com/github/gchn24/DS-Notes/blob/main/DAV_3_Revision_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import  matplotlib.pyplot as plt
from scipy.stats import geom,binom

# %% [markdown]
# # Binomal Distribution

# %%
x_val=np.arange(0,11)
y_val=binom.pmf(n=10,k=x_val,p=0.5)
sns.barplot(x=x_val,y=y_val)
# Out:
# <Axes: >

# %%
1-binom.cdf(n=10,k=6,p=0.5)
# Out:
# 0.171875

# %%
binom.pmf(n=10,k=10,p=0.5)+binom.pmf(n=10,k=7,p=0.5)+binom.pmf(n=10,k=8,p=0.5)+binom.pmf(n=10,k=9,p=0.5)
# Out:
# 0.17187500000000003

# %%
1-binom.cdf(n=100,k=69,p=0.5)
# Out:
# 3.925069822796612e-05

# %%
1-binom.cdf(n=1000,k=699,p=0.5)
# Out:
# 0.0

# %%
1-binom.cdf(n=1000,k=699,p=0.7)
# Out:
# 0.5155935198141187

# %% [markdown]
# # Geometric Distribution

# %%
p=0.1

# %%
print(p)
geom.pmf(k=1,p=0.1)
# Out:
# 0.1
# 0.1

# %%
print((1-p)*p)
geom.pmf(k=2,p=0.1)
# Out:
# 0.09000000000000001
# 0.09000000000000001

# %%
print((1-p)*(1-p)*p)
geom.pmf(k=3,p=0.1)
# Out:
# 0.08100000000000002
# 0.08100000000000002

# %%
print((1-p)*(1-p)*(1-p)*p)
geom.pmf(k=4,p=0.1)
# Out:
# 0.0729
# 0.0729

# %%
x=np.arange(0,50)
p=0.1

# %%
sns.barplot(x=x,y=geom.pmf(k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,10)
p=0.4
sns.barplot(x=x,y=geom.pmf(k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,10)
p=0.9
sns.barplot(x=x,y=geom.pmf(k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,10)
p=0.1
sns.barplot(x=x,y=geom.pmf(k=x,p=p))
# Out:
# <Axes: >

# %%
geom.cdf(k=5,p=0.1)
# Out:
# 0.40951000000000004

# %%
geom.cdf(k=5,p=0.9)
# Out:
# 0.99999

# %%
x=np.arange(0,10)
p=0.9
sns.barplot(x=x,y=geom.cdf(k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,10)
p=0.1
sns.barplot(x=x,y=geom.cdf(k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,11)
p=0.1
n=10
sns.barplot(x=x,y=binom.pmf(n=n,k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,11)
p=0.1
n=10
sns.barplot(x=x,y=binom.cdf(n=n,k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,11)
p=0.5
n=10
sns.barplot(x=x,y=binom.cdf(n=n,k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,11)
p=0.5
n=10
sns.barplot(x=x,y=binom.pmf(n=n,k=x,p=p))
# Out:
# <Axes: >

# %%
x=np.arange(0,11)
p=0.9
n=10
sns.barplot(x=x,y=binom.pmf(n=n,k=x,p=p))
# Out:
# <AxesSubplot:>

# %%
x=np.arange(0,11)
p=0.9
n=10
sns.barplot(x=x,y=binom.cdf(n=n,k=x,p=p))
# Out:
# <Axes: >

# %% [markdown]
# # Hypothesis Testing

# %%
pd.value_counts(np.random.choice(["T","H"],size=1000))
# Out:
# T    514
# H    486
# dtype: int64

# %%
pd.value_counts(np.random.choice(["H","T"],size=10))
# Out:
# T    5
# H    5
# dtype: int64

# %%
h_val=[]
for i in range(1000):
    size=100000
    h_val.append(pd.value_counts(np.random.choice(["T","H"],size=size))["H"]/size)
sns.kdeplot((h_val))
# Out:
# <Axes: ylabel='Density'>

# %%
h_val=[]
for i in range(1000):
    size=1000
    h_val.append(pd.value_counts(np.random.choice(["T","H"],size=size))["H"]/size)
sns.kdeplot((h_val))
# Out:
# <Axes: ylabel='Density'>

# %%
h_val=[]
for i in range(1000):
    size=100000
    h_val.append(pd.value_counts(np.random.choice(["T","H"],size=size))["H"]/size)
sns.histplot((h_val))
# Out:
# <Axes: ylabel='Count'>

# %%
h_val=[]
for i in range(1000):
    size=100000
    h_val.append(pd.value_counts(np.random.choice(["T","H"],size=size))["H"]/size)
sns.displot((h_val),kde=True)

# %% [markdown]
# # Normal Distribution

# %%
from scipy.stats import norm

# %%
1-norm.cdf(x=1850,loc=1800,scale=(100/np.sqrt(50)))
# Out:
# 0.00020347600872250293

# %%
1-norm.cdf((1850-1800)/((100/np.sqrt(50))))
# Out:
# 0.00020347600872250293

# %%
1-norm.cdf(x=1900,loc=1800,scale=(100/np.sqrt(5)))
# Out:
# 0.0126736593387341

# %%
1-norm.cdf((1900-1800)/((100/np.sqrt(5))))
# Out:
# 0.0126736593387341

# %%
(1900-1800)/((100/np.sqrt(5)))
# Out:
# 2.23606797749979

# %%
1-0.98713
# Out:
# 0.012870000000000048

# %%
1-binom.cdf(n=10,k=6,p=0.5)
# Out:
# 0.171875

# %%
1-binom.cdf(n=100,k=69,p=0.5)
# Out:
# 3.925069822796612e-05

# %%
1-binom.cdf(n=1000,k=699,p=0.5)
# Out:
# 0.0

# %%
pd.value_counts(np.random.choice(["H","T"],size=100000))
# Out:
# T    50112
# H    49888
# dtype: int64

# %%
norm.ppf(q=.99,loc=1800,scale=((100/np.sqrt(50))))
# Out:
# 1832.8995271426638

# %%
norm.ppf(q=.95,loc=1800,scale=((100/np.sqrt(50))))
# Out:
# 1823.2617430735336

# %%
norm.ppf(q=.99,loc=1800,scale=((100/np.sqrt(5))))
# Out:
# 1904.0374397133487

# %%
norm.ppf(q=.95,loc=1800,scale=((100/np.sqrt(5))))
# Out:
# 1873.5600904580115

# %%
norm.ppf(0.99)
# Out:
# 2.3263478740408408

# %%
norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
norm.ppf(0.05)
# Out:
# -1.6448536269514729

# %%
norm.ppf(0.025)
# Out:
# -1.9599639845400545

# %%
norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
1-norm.cdf(x=1850,loc=1800,scale=((100/np.sqrt(50))))
# Out:
# 0.00020347600872250293

# %%
1-norm.cdf(x=1900,loc=1800,scale=((100/np.sqrt(5))))
# Out:
# 0.0126736593387341

# %% [markdown]
# # Z - Test

# %%
from scipy.stats import norm, t

# %% [markdown]
# ## Pastries

# %% [markdown]
# A french cake shop claims that the average number of pastries they can produce in a day exceeds 500. The average number of pastries produced per day over a 70 day period was found to be 530. Assume that the population standard deviation for the pastries produced per day is 125. Test the claim using a z-test with the critical z-value = 1.64 at the alpha (significance level) = 0.05, and state your interpretation.

# %%
# Ho : mu = 500
# Ha : mu > 500

z_stat= (530-500)/(125/np.sqrt(70))
print("z_stat: ",z_stat)
alpha = 0.05
print("alpha: ",alpha)
p_value=1-norm.cdf(z_stat)
print("p_value: ",p_value)

if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# z_stat:  2.007984063681781
# alpha:  0.05
# p_value:  0.022322492581293485
# Interpretation : Reject Ho

# %%
z_critical_value=norm.ppf(0.95)
print("z_critical_value: ",z_critical_value)
# Out:
# z_critical_value:  1.6448536269514722

# %%
# z = (x-mu)/(125/np.sqrt(70))
critical_value=500 + z_critical_value*((125/np.sqrt(70)))
print("critical_value: ",critical_value)
# Out:
# critical_value:  524.574701413748

# %%
norm.ppf(q=0.95,loc=500,scale=(125/np.sqrt(70)))
# Out:
# 524.574701413748

# %%
observed = 530
# For a right tailed test
if critical_value <observed :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Reject Ho

# %% [markdown]
# # T - test (One sample)

# %%
from scipy.stats import ttest_1samp, ttest_ind

# %% [markdown]
# ## Improve IQ with a pill

# %% [markdown]
# Population IQ average = 100
#
#
# One researcher claims that his pill will improve IQ

# %%
# The pill is given to a few people and their IQ is tested with following results:
iq_scores = [110, 105, 98, 102, 99, 104, 115, 95]

# %%
np.mean(iq_scores)
# Out:
# 103.5

# %%
# Ho : mu = 100
# Ha : mu > 100

# %% [markdown]
# Establish result at 99% confidence (0.01 significance "alpha")
#
#
# Here we use T-test
#
#
# H0: mu = 100 (pill has no effect)
#
#
#
# Ha: mu > 100 (pill has good effect)

# %%
t_statistic,p_value=ttest_1samp(iq_scores,100,alternative="greater")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  1.5071573172061195
# p_value:  0.08774972467925055

# %%
alpha = 0.01
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Fail to Reject Ho

# %%
t_statistic1=(103.5-100)/(pd.Series(iq_scores).std()/np.sqrt(8))
print("t_statistic1: ",t_statistic1)
# Out:
# t_statistic1:  1.5071573172061195

# %%
1-t.cdf(t_statistic1,df=7)
# Out:
# 0.08774972467925057

# %% [markdown]
# # T Distribution

# %%
x_values= np.linspace(-10,10,1000)
y_values= norm.cdf(x_values)

plt.plot(x_values,y_values,color="green")

y_values1= t.cdf(x_values,df=30)

plt.plot(x_values,y_values1,color="blue")

# %% [markdown]
# # T - test (two samples)

# %% [markdown]
# ## IQ across 2 schools

# %%
df_iq = pd.read_csv("iq_two_schools.csv")

# %%
df_iq.head()
# Out:
#      School   iq
# 0  school_1   91
# 1  school_1   95
# 2  school_1  110
# 3  school_1  112
# 4  school_1  115

# %%
iq_1=df_iq.loc[df_iq["School"]=="school_1"]["iq"]
iq_2=df_iq.loc[df_iq["School"]=="school_2"]["iq"]

# %%
iq_1.mean()
# Out:
# 101.15384615384616

# %%
iq_2.mean()
# Out:
# 109.41666666666667

# %%
# Ho : mu1 = mu2
# Ha : mu1 != mu2

# %%
t_statistic,p_value=ttest_ind(iq_1,iq_2,alternative="two-sided")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  -2.4056474861512704
# p_value:  0.02004552710936217

# %%
alpha = 0.01
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Fail to Reject Ho

# %%
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Reject Ho

# %%
# Ho : mu1 = mu2
# Ha : mu1 < mu2
t_statistic,p_value=ttest_ind(iq_1,iq_2,alternative="less")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  -2.4056474861512704
# p_value:  0.010022763554681085

# %%
# Ho : mu1 = mu2
# Ha : mu2 > mu1
t_statistic,p_value=ttest_ind(iq_2,iq_1,alternative="greater")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  2.4056474861512704
# p_value:  0.010022763554681085

# %%
# Ho : mu1 = mu2
# Ha : mu1 > mu2
t_statistic,p_value=ttest_ind(iq_1,iq_2,alternative="greater")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  -2.4056474861512704
# p_value:  0.9899772364453189

# %% [markdown]
# ## Cricket

# %%
df = pd.read_csv("Sachin_ODI.csv")

# %%
df
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30   15      3      0   86.66     1   New Zealand
# 1      37       0   75   51      3      1   72.54     2  South Africa
# 2      47       0   65   40      7      0  117.50     2     Australia
# 3      48       0   37   30      9      1  160.00     2    Bangladesh
# 4       4       0   13    9      1      0   44.44     2      Pakistan
# ..    ...     ...  ...  ...    ...    ...     ...   ...           ...
# 355    14       0   34   15      2      0   93.33     2     Australia
# 356    39       0   45   30      5      0  130.00     2     Sri Lanka
# 357     6       0   25   19      1      0   31.57     1     Sri Lanka
# 358   114       0  205  147     12      1   77.55     1    Bangladesh
# 359    52       0   93   48      5      1  108.33     2      Pakistan
#
#        Ground        Date        Winner    Won  century
# 0      Napier  1995-02-16   New Zealand  False    False
# ...

# %%
df.groupby("Inns")["runs"].mean()
# Out:
# Inns
# 1    46.670588
# 2    40.173684
# Name: runs, dtype: float64

# %% [markdown]
# ### Batting pattern in first and second innings

# %%
df_first_innings = df.loc[df["Inns"]==1]["runs"]
df_second_innings = df.loc[df["Inns"]==2]["runs"]

# %%
# Ho : mu1 = mu2 ( first and second innings performace are similar)
# Ha : mu1 > mu2 ( first inning's performace is better than second inning's performace)
# first inning's performace is significantly better
t_statistic,p_value=ttest_ind(df_first_innings,df_second_innings,alternative="greater")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  1.4612016295532178
# p_value:  0.07241862097379981

# %%
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Fail to Reject Ho

# %%
# Ho : mu1 = mu2 ( first and second innings performace are similar)
# Ha : mu1 < mu2
t_statistic,p_value=ttest_ind(df_first_innings,df_second_innings,alternative="less")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  1.4612016295532178
# p_value:  0.9275813790262002

# %%
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Fail to Reject Ho

# %% [markdown]
# ### Victory Vs Defeat

# %%
df.groupby("Won")["runs"].mean()
# Out:
# Won
# False    35.130682
# True     51.000000
# Name: runs, dtype: float64

# %%
df_won = df[df["Won"]==True]["runs"]
df_lost = df[df["Won"]==False]["runs"]

# %%
# Ho : mu_won = mu_lost (India Winning or losing , sachin's  performace are similar)
# Ha : mu_won > mu_lost ( Sachin's performance when India Wins is significantly better than when India loses)

t_statistic,p_value=ttest_ind(df_won,df_lost,alternative="greater")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
# Out:
# t_statistic:  3.628068563969343
# p_value:  0.00016353077486826558

# %%
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# Interpretation : Reject Ho

# %% [markdown]
# ## Aerofit

# %%
df_aerofit = pd.read_csv("aerofit.csv")

# %%
df_aerofit.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# ### Gender Vs Income

# %%
sns.boxplot(x='Gender', y='Income', data=df_aerofit)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Income'>

# %%
income_male = df_aerofit[df_aerofit["Gender"]=="Male"]["Income"]
income_female = df_aerofit[df_aerofit["Gender"]=="Female"]["Income"]

# %%
income_male.mean()
# Out:
# 56562.75961538462

# %%
income_female.mean()
# Out:
# 49828.90789473684

# %%
# H0: same income
# Ha: men having more income
t_stat, p_value = ttest_ind(income_male, income_female, alternative="greater")
print(p_value)
if p_value < 0.05:
    print("Reject H0")
# Out:
# 0.003263631548607129
# Reject H0

# %% [markdown]
# # Optional Post Read - T test from scratch

# %%
def ttest_ind_from_scratch(d1, d2, alternative="two-sided"):
    """
    d1: pandas Series
    d2: pandas Series
    alternative: {‘two-sided’, ‘less’, ‘greater’}, optional
    """
    n1 = len(d1)
    n2 = len(d2)

    m1 = d1.mean()
    m2 = d2.mean()

    s1 = d1.std()
    s2 = d2.std()

    df = n1 + n2 - 2

    s = np.sqrt((((n1-1)*(s1**2)) + ((n2-1)*(s2**2))) / (n1 + n2 - 2))

    t_stat = (m1 - m2) / (s*np.sqrt(1/n1+ 1/n2))

    if alternative == "two-sided":
        p_value = 2*(1 - t.cdf(t_stat, df=df))
    if alternative == "less":
        p_value = t.cdf(t_stat, df=df)
    if alternative == "greater":
        p_value = 1 - t.cdf(t_stat, df=df)
    print("T-stat = ", t_stat)
    print("P-value = ", p_value)
    return [t_stat, p_value]

# %%
ttest_ind_from_scratch(income_male, income_female, alternative="greater")
# Out:
# T-stat =  2.752488637540257
# P-value =  0.0032636315486070933
# [2.752488637540257, 0.0032636315486070933]

# %%
from scipy.stats import chi2 # Distribution (cdf etc.)
from scipy.stats import chisquare # Statistical test (chistat, pvalue)
from scipy.stats import chi2_contingency # Categorical Vs Categorical
from scipy.stats import ttest_rel

# %% [markdown]
# # T Test Rel

# %%
df=pd.read_csv("problem_solving.csv")
df
# Out:
#       id  test_1  test_2
# 0      0      40      38
# 1      1      49      44
# 2      2      65      69
# 3      3      59      63
# 4      4      44      43
# ..   ...     ...     ...
# 132  132      45      44
# 133  133      46      42
# 134  134      40      35
# 135  135      60      66
# 136  136      79      84
#
# [137 rows x 3 columns]

# %%
df["test_1"].mean()
# Out:
# 60.48905109489051

# %%
df["test_2"].mean()
# Out:
# 62.43065693430657

# %%
# Ho : mu1 = mu2 ( There is not effect of interview prep session)
# Ha : mu1 < mu2 ( There is effect of interview prep session)
t_statistic,p_value=ttest_rel(df["test_1"],df["test_2"],alternative="less")
print("t_statistic: ",t_statistic)
print("p_value: ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# t_statistic:  -5.502886353508166
# p_value:  8.979201768961566e-08
# Interpretation : Reject Ho

# %% [markdown]
# # Chi Square Test

# %%
df=pd.read_csv("Sachin_ODI.csv")
df
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30   15      3      0   86.66     1   New Zealand
# 1      37       0   75   51      3      1   72.54     2  South Africa
# 2      47       0   65   40      7      0  117.50     2     Australia
# 3      48       0   37   30      9      1  160.00     2    Bangladesh
# 4       4       0   13    9      1      0   44.44     2      Pakistan
# ..    ...     ...  ...  ...    ...    ...     ...   ...           ...
# 355    14       0   34   15      2      0   93.33     2     Australia
# 356    39       0   45   30      5      0  130.00     2     Sri Lanka
# 357     6       0   25   19      1      0   31.57     1     Sri Lanka
# 358   114       0  205  147     12      1   77.55     1    Bangladesh
# 359    52       0   93   48      5      1  108.33     2      Pakistan
#
#        Ground        Date        Winner    Won  century
# 0      Napier  1995-02-16   New Zealand  False    False
# ...

# %%
pd.crosstab(index=df["Won"],columns=df["century"],margins=True)
# Out:
# century  False  True  All
# Won
# False      160    16  176
# True       154    30  184
# All        314    46  360

# %%
(((28-25)**2)/25) + ((( 22-25)**2)/25)
# Out:
# 0.72

# %%
# Ho : coin is fair
# Ha : coin is not fair


1-chi2.cdf(0.72,df=1)
# Out:
# 0.3961439091520741

# %%
# Ho : coin is fair
# Ha : coin is not fair
chi_stat,p_value=chisquare([28,22],[25,25])
print("chi_stat : ",chi_stat)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# chi_stat :  0.72
# p_value :  0.3961439091520741
# Interpretation : Fail to Reject Ho

# %%
# Ho : coin is fair
# Ha : coin is not fair
chi_stat,p_value=chisquare([45,5],[25,25])
print("chi_stat : ",chi_stat)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# chi_stat :  32.0
# p_value :  1.5417257900280013e-08
# Interpretation : Reject Ho

# %%
critical_chi_stat_value=chi2.ppf(0.95,df=1)
print("critical_chi_stat_value : ",critical_chi_stat_value)
# Out:
# critical_chi_stat_value :  3.841458820694124

# %%
# Ho : Gender Doesnt affect ( independant)
# Ha : Gender Affects buying pattern ( dependant)

observed = [[527,72],[206,102]]
chi_stat,p_value,df,expected_freq=chi2_contingency(observed)
print("chi_stat : ",chi_stat)
print("p_value : ",p_value)
print("df : ",df)
print("expected_freq : ",expected_freq)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# chi_stat :  57.04098674049609
# p_value :  4.268230756875865e-14
# df :  1
# expected_freq :  [[484.08710033 114.91289967]
#  [248.91289967  59.08710033]]
# Interpretation : Reject Ho

# %% [markdown]
# ## Aerofit

# %%
df=pd.read_csv("aerofit.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# ### Gender Vs Product

# %%
gender_product= pd.crosstab(columns=df["Product"],index=df["Gender"])
gender_product
# Out:
# Product  KP281  KP481  KP781
# Gender
# Female      40     29      7
# Male        40     31     33

# %%
# Ho : Gender Doesnt affect ( independant)
# Ha : Gender Affects buying pattern ( dependant)


chi_stat,p_value,df,expected_freq=chi2_contingency(gender_product)
print("chi_stat : ",chi_stat)
print("p_value : ",p_value)
print("df : ",df)
print("expected_freq : ",expected_freq)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# chi_stat :  12.923836032388664
# p_value :  0.0015617972833158714
# df :  2
# expected_freq :  [[33.77777778 25.33333333 16.88888889]
#  [46.22222222 34.66666667 23.11111111]]
# Interpretation : Reject Ho

# %% [markdown]
# ### Income vs Product

# %%
sns.boxplot(x=df["Product"],y=df["Income"])
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Income'>

# %%
bins= [0 , df["Income"].median(),df["Income"].max()]
labels = ["low","high"]
df["income_bin"]=pd.cut(x=df["Income"],bins=bins, labels=labels)
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles income_bin
# 0      112        low
# 1       75        low
# ...

# %%
income_product= pd.crosstab(columns=df["Product"],index=df["income_bin"])
income_product
# Out:
# Product     KP281  KP481  KP781
# income_bin
# low            50     35      5
# high           30     25     35

# %%
# Ho : Income Doesnt affect ( independant)
# Ha : Income Affects buying pattern ( dependant)


chi_stat,p_value,dof,expected_freq=chi2_contingency(income_product)
print("chi_stat : ",chi_stat)
print("p_value : ",p_value)
print("dof : ",dof)
print("expected_freq : ",expected_freq)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# chi_stat :  29.166666666666668
# p_value :  4.640222499769401e-07
# df :  2
# expected_freq :  [[40. 30. 20.]
#  [40. 30. 20.]]
# Interpretation : Reject Ho

# %% [markdown]
# ### Income vs Gender

# %%
income_gender= pd.crosstab(columns=df["Gender"],index=df["income_bin"])
income_gender
# Out:
# Gender      Female  Male
# income_bin
# low             46    44
# high            30    60

# %%
# Ho : Gender Doesnt affect Income ( independant)
# Ha : Gender  affects Income ( dependant)


chi_stat,p_value,dof,expected_freq=chi2_contingency(income_gender)
print("chi_stat : ",chi_stat)
print("p_value : ",p_value)
print("dof : ",dof)
print("expected_freq : ",expected_freq)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# chi_stat :  5.123987854251013
# p_value :  0.023597328751612023
# dof :  1
# expected_freq :  [[38. 52.]
#  [38. 52.]]
# Interpretation : Reject Ho

# %% [markdown]
# # ANOVA

# %% [markdown]
# ## Aerofit --> `Anova`

# %%
from scipy.stats import f,f_oneway
from scipy.stats import kruskal,shapiro,ttest_ind,levene

from statsmodels.graphics.gofplots import qqplot

# %%
df=pd.read_csv("aerofit.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df["Product"].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %%
sns.boxplot(x="Product",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Income'>

# %%
df["random_group"]=np.random.choice(["g1","g2","g3"],size=len(df))

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles random_group
# 0      112           g3
# 1       75           g3
# ...

# %%
sns.boxplot(x="random_group",y="Income",data=df)
# Out:
# <AxesSubplot:xlabel='random_group', ylabel='Income'>

# %% [markdown]
# ## Anova Calculations

# %%
a = np.array([25, 25, 27, 30, 23, 20])
b = np.array([30, 30, 21, 24, 26, 28])
c = np.array([18, 30, 29, 29, 24, 26])

# Step 1: Compute the individual means.
m1 = a.mean()
m2 = b.mean()
m3 = c.mean()

print(m1, m2, m3)
# Out:
# 25.0 26.5 26.0

# %%
# Step 2: Compute the overall mean.
m_o = (m1 + m2 + m3)/3
m_o
# Out:
# 25.833333333333332

# %%
# Step 3 : compute variance between groups
# sum of square between groups
ssb = (len(a) * (m1-m_o)**2) + (len(b) * (m2-m_o)**2) +(len(c) * (m3-m_o)**2)
ssb
# Out:
# 6.999999999999999

# %%
dof_between_groups= 3-1 # number of groups-1
dof_between_groups
# Out:
# 2

# %%
# Mean sum of square between groups
msb= ssb/dof_between_groups
msbmsw = ssw/dof_within_groups
msw
# Out:
# 3.4999999999999996

# %%
# step 4 :compute variance withing groups

ssw_a= ((a-m1)**2).sum()
ssw_b= ((b-m2)**2).sum()
ssw_c= ((c-m3)**2).sum()
ssw = ssw_a+ssw_b+ssw_c
ssw
# Out:
# 223.5

# %%
dof_within_groups= 18-3 # total number of observations - number of groups
dof_within_groups
# Out:
# 15

# %%
msw = ssw/dof_within_groups
msw
# Out:
# 14.9

# %%
f_ratio= msb/msw
f_ratio
# Out:
# 0.23489932885906037

# %%
p_value=1-f.cdf(f_ratio,dfn=dof_between_groups,dfd=dof_within_groups)
print("f_stat : ",f_ratio)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# f_stat :  0.23489932885906037
# p_value :  0.7935046627328333
# Interpretation : Fail to Reject Ho

# %%
f_stat,p_value=f_oneway(a,b,c)
print("f_stat : ",f_ratio)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# f_stat :  0.23489932885906037
# p_value :  0.793504662732833
# Interpretation : Fail to Reject Ho

# %%
f.ppf(0.95,dfn=dof_between_groups,dfd=dof_within_groups)
# Out:
# 3.6823203436732412

# %% [markdown]
# ## Aerofit

# %% [markdown]
# ### Income Vs Random_group

# %%
income_g1 = df[df["random_group"]=="g1"]["Income"]
income_g2 = df[df["random_group"]=="g2"]["Income"]
income_g3 = df[df["random_group"]=="g3"]["Income"]

# %%
income_g1.mean()
# Out:
# 52487.40625

# %%
income_g2.mean()
# Out:
# 54457.90476190476

# %%
income_g3.mean()
# Out:
# 54329.84905660377

# %%
# Ho : All have same means
# Ha : One or more groups have different means

f_stat,p_value=f_oneway(income_g1,income_g2,income_g3)
print("f_stat : ",f_ratio)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# f_stat :  0.23489932885906037
# p_value :  0.7596652157664745
# Interpretation : Fail to Reject Ho

# %%
# Ho : All have same means
# Ha : One or more groups have different means

f_stat,p_value=kruskal(income_g1,income_g2,income_g3)
print("f_stat : ",f_ratio)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# f_stat :  0.23489932885906037
# p_value :  0.5065907917197695
# Interpretation : Fail to Reject Ho

# %% [markdown]
# ### Income vs Product

# %%
income_kp281 = df[df["Product"]=="KP281"]["Income"]
income_kp481 = df[df["Product"]=="KP481"]["Income"]
income_kp781 = df[df["Product"]=="KP781"]["Income"]

# %%
income_kp281.mean()
# Out:
# 46418.025

# %%
income_kp481.mean()
# Out:
# 48973.65

# %%
income_kp781.mean()
# Out:
# 75441.575

# %%
# Ho : All have same means
# Ha : One or more groups have different means

f_stat,p_value=f_oneway(income_kp281,income_kp481,income_kp781)
print("f_stat : ",f_ratio)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# f_stat :  0.23489932885906037
# p_value :  1.5644991316342494e-27
# Interpretation : Reject Ho

# %%
# Ho : All have same means
# Ha : One or more groups have different means

f_stat,p_value=kruskal(income_kp281,income_kp481,income_kp781)
print("f_stat : ",f_ratio)
print("p_value : ",p_value)
alpha = 0.05
if p_value <alpha :
    print("Interpretation : Reject Ho")
else:
    print("Interpretation : Fail to Reject Ho")
# Out:
# f_stat :  0.23489932885906037
# p_value :  4.562357014275808e-14
# Interpretation : Reject Ho

# %%
sns.kdeplot(x="Income",hue="Product",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %% [markdown]
# ## QQ Plot

# %%
df1=pd.read_csv("weight-height.csv")
df1
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df1["Height"].mean()
# Out:
# 66.36755975482106

# %%
sns.histplot(df1["Height"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
sns.displot(df1["Height"],kde=True)

# %%
qqplot(df1["Height"],line="s")
plt.show()

# %%
df2=pd.read_csv("waiting_time.csv")
df2
# Out:
#              time
# 0      184.003075
# 1       36.721521
# 2       29.970417
# 3       75.640285
# 4       61.489439
# ...           ...
# 90041  135.885984
# 90042   15.223970
# 90043  207.839528
# 90044  140.488418
# 90045   50.719544
#
# [90046 rows x 1 columns]

# %%
sns.displot(df2["time"],kde=True)

# %%
qqplot(df2["time"],line="s")
plt.show()

# %% [markdown]
# ## Wilkin Shapiro Test

# %% [markdown]
# Take a few data usually ranging between [50 - 200]
#
#
# The test may not work if the data points are <50 or if the data is too large

# %%
height_sample=df1["Height"].sample(100)
height_sample
# Out:
# 2435    71.539299
# 7568    65.363737
# 4782    70.654439
# 3863    72.657404
# 6827    64.085739
#           ...
# 7944    64.539260
# 4309    71.625601
# 9285    54.263133
# 6029    62.495681
# 7793    68.254363
# Name: Height, Length: 100, dtype: float64

# %%
# Ho : Data is Gaussian
# Ha : Data is not Gaussian
shapiro(height_sample)
# Out:
# ShapiroResult(statistic=0.9863835573196411, pvalue=0.39752107858657837)

# %%
time_sample=df2["time"].sample(50)

# %%
# Ho : Data is Gaussian
# Ha : Data is not Gaussian
shapiro(time_sample)
# Out:
# ShapiroResult(statistic=0.7641297578811646, pvalue=1.4353095423302875e-07)

# %% [markdown]
# ## Levene Test

# %%
sns.histplot(data=df1, x="Height", hue="Gender")
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
height_men = df1[df1["Gender"]=="Male"]["Height"]
height_women = df1[df1["Gender"]=="Female"]["Height"]

# %%
height_men.mean()
# Out:
# 69.02634590621737

# %%
height_women.mean()
# Out:
# 63.708773603424916

# %%
ttest_ind(height_men,height_women)
# Out:
# Ttest_indResult(statistic=95.60271449148823, pvalue=0.0)

# %%
height_men.var()
# Out:
# 8.19884325252049

# %%
height_women.var()
# Out:
# 7.269947493670132

# %%
# H0: Variances are equal
# Ha: Variances are not equal
levene_stat, p_value = levene(height_men, height_women)
if p_value < 0.05:
    print("Reject Ho")
    print("Variances are not equal")
# Out:
# Reject Ho
# Variances are not equal

# %% [markdown]
# # Correlation Tests

# %%
from scipy.stats import pearsonr, spearmanr

# %%
heights = np.array([68, 62, 64, 61, 70, 66, 61, 65, 71, 72]) # inches
weights = np.array([72, 58, 67, 72, 79, 61, 68, 64, 80, 79]) # kgs

sns.scatterplot(x=heights, y=weights)
plt.axvline(heights.mean(),color="green",linestyle="--")
plt.axhline(weights.mean(),color="green",linestyle="--")

plt.xlabel("Heights (inches)")
plt.ylabel("Weights (Kgs)")
plt.show()

# %%
covariance=(((heights-heights.mean())*(weights-weights.mean())).sum())/len(heights)
print("Covariance : ",covariance)
# Out:
# Covariance :  20.4

# %%
corr = covariance/(weights.std()*heights.std())
print("Correlation : ",corr)
# Out:
# Correlation :  0.7094289771951879

# %%
heights1 = np.array([68, 62, 64, 61, 70, 66, 61, 65, 71, 72])*2.54 # cms
weights1 = np.array([72, 58, 67, 72, 79, 61, 68, 64, 80, 79])*1000 # gms

sns.scatterplot(x=heights1, y=weights1)
plt.axvline(heights1.mean(),color="green",linestyle="--")
plt.axhline(weights1.mean(),color="green",linestyle="--")

plt.xlabel("Heights (cms)")
plt.ylabel("Weights (gms)")
plt.show()

# %%
covariance1=(((heights1-heights1.mean())*(weights1-weights1.mean())).sum())/len(heights1)
print("Covariance : ",covariance1)
# Out:
# Covariance :  51816.00000000001

# %%
corr1 = covariance1/(weights1.std()*heights1.std())
print("Correlation : ",corr1)
# Out:
# Correlation :  0.7094289771951878

# %%
print("Covariance1 : ",covariance)
print("Covariance2 : ",covariance1)
# Out:
# Covariance1 :  20.4
# Covariance2 :  51816.00000000001

# %%
print("Correlation1 : ",corr)
print("Correlation2 : ",corr1)
# Out:
# Correlation1 :  0.7094289771951879
# Correlation2 :  0.7094289771951878

# %%
np.corrcoef(weights,heights)
# Out:
# array([[1.        , 0.70942898],
#        [0.70942898, 1.        ]])

# %%
pearsonr(weights,heights)
# Out:
# (0.7094289771951878, 0.021575164034828447)

# %%
covariance2=(((heights1-heights1.mean())*(heights1-heights1.mean())).sum())/len(heights1)
print("Covariance : ",covariance2)
# Out:
# Covariance :  98.06432000000007

# %%
corr2 = covariance2/(heights1.std()*heights1.std())
print("Correlation : ",corr2)
# Out:
# Correlation :  1.0000000000000002

# %%
heights = np.array([68, 62, 64, 61, 70, 66, 61, 65, 71, 72])
weights = np.array([72, 58, 67, 72, 79, 61, 68, 64, 80, 79])
df=pd.DataFrame([weights,heights]).transpose()
df
# Out:
#     0   1
# 0  72  68
# 1  58  62
# 2  67  64
# 3  72  61
# 4  79  70
# 5  61  66
# 6  68  61
# 7  64  65
# 8  80  71
# 9  79  72

# %%
df2=df.rank()
df2
# Out:
#       0     1
# 0   6.5   7.0
# 1   1.0   3.0
# 2   4.0   4.0
# 3   6.5   1.5
# 4   8.5   8.0
# 5   2.0   6.0
# 6   5.0   1.5
# 7   3.0   5.0
# 8  10.0   9.0
# 9   8.5  10.0

# %%
sns.scatterplot(x=df[0], y=df[1])
plt.axvline(df[0].mean(),color="green",linestyle="--")
plt.axhline(df[1].mean(),color="green",linestyle="--")

plt.xlabel("Heights (inches)")
plt.ylabel("Weights (Kgs)")
plt.show()

# %%
sns.scatterplot(x=df2[0], y=df2[1])
plt.axvline(df2[0].mean(),color="green",linestyle="--")
plt.axhline(df2[1].mean(),color="green",linestyle="--")

plt.xlabel("Heights (inches)")
plt.ylabel("Weights (Kgs)")
plt.show()

# %%
df_mpg=sns.load_dataset('mpg')
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(x=df_mpg["mpg"], y=df_mpg["weight"])
plt.axvline(df_mpg["mpg"].mean(),color="green",linestyle="--")
plt.axhline(df_mpg["weight"].mean(),color="green",linestyle="--")


plt.show()

# %%
pearsonr(df_mpg["mpg"],df_mpg["weight"])
# Out:
# (-0.8317409332443348, 2.9727995640500577e-103)

# %%
spearmanr(df_mpg["mpg"],df_mpg["weight"])
# Out:
# SpearmanrResult(correlation=-0.8749473981990713, pvalue=8.643768710424627e-127)

# %%
df1=pd.DataFrame([df_mpg["mpg"],df_mpg["weight"]]).transpose()
df1
# Out:
#       mpg  weight
# 0    18.0  3504.0
# 1    15.0  3693.0
# 2    18.0  3436.0
# 3    16.0  3433.0
# 4    17.0  3449.0
# ..    ...     ...
# 393  27.0  2790.0
# 394  44.0  2130.0
# 395  32.0  2295.0
# 396  28.0  2625.0
# 397  31.0  2720.0
#
# [398 rows x 2 columns]

# %%
df2=df1.rank()
df2
# Out:
#        mpg  weight
# 0    116.0   290.0
# 1     61.5   309.0
# 2    116.0   284.0
# 3     81.0   283.0
# 4     96.0   287.0
# ..     ...     ...
# 393  270.0   197.0
# 394  395.0    73.5
# 395  333.5   117.0
# 396  285.5   169.0
# 397  321.0   188.0
#
# [398 rows x 2 columns]

# %% [markdown]
# ## Correlation

# %%
df=pd.read_csv("Sachin_ODI.csv")
df
# Out:
#      runs  NotOut mins   bf  fours  sixes      sr  Inns           Opp  \
# 0      13       0   30   15      3      0   86.66     1   New Zealand
# 1      37       0   75   51      3      1   72.54     2  South Africa
# 2      47       0   65   40      7      0  117.50     2     Australia
# 3      48       0   37   30      9      1  160.00     2    Bangladesh
# 4       4       0   13    9      1      0   44.44     2      Pakistan
# ..    ...     ...  ...  ...    ...    ...     ...   ...           ...
# 355    14       0   34   15      2      0   93.33     2     Australia
# 356    39       0   45   30      5      0  130.00     2     Sri Lanka
# 357     6       0   25   19      1      0   31.57     1     Sri Lanka
# 358   114       0  205  147     12      1   77.55     1    Bangladesh
# 359    52       0   93   48      5      1  108.33     2      Pakistan
#
#        Ground        Date        Winner    Won  century
# 0      Napier  1995-02-16   New Zealand  False    False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   runs     360 non-null    int64
#  1   NotOut   360 non-null    int64
#  2   mins     360 non-null    object
#  3   bf       360 non-null    int64
#  4   fours    360 non-null    int64
#  5   sixes    360 non-null    int64
#  6   sr       360 non-null    float64
#  7   Inns     360 non-null    int64
#  8   Opp      360 non-null    object
#  9   Ground   360 non-null    object
#  10  Date     360 non-null    object
#  11  Winner   360 non-null    object
#  12  Won      360 non-null    bool
#  13  century  360 non-null    bool
# dtypes: bool(2), float64(1), int64(6), object(5)
# memory usage: 34.6+ KB

# %%
df.corr()
# Out:
#              runs    NotOut        bf     fours     sixes        sr      Inns  \
# runs     1.000000  0.377869  0.953558  0.907861  0.604078  0.576354 -0.076998
# NotOut   0.377869  1.000000  0.324253  0.360667  0.266437  0.210590  0.104015
# bf       0.953558  0.324253  1.000000  0.841240  0.487939  0.419307 -0.114803
# fours    0.907861  0.360667  0.841240  1.000000  0.414766  0.613975 -0.014255
# sixes    0.604078  0.266437  0.487939  0.414766  1.000000  0.415239 -0.045657
# sr       0.576354  0.210590  0.419307  0.613975  0.415239  1.000000  0.058539
# Inns    -0.076998  0.104015 -0.114803 -0.014255 -0.045657  0.058539  1.000000
# Won      0.188319  0.214461  0.153881  0.225120  0.063837  0.174703  0.043287
# century  0.751176  0.336174  0.696394  0.591924  0.547777  0.292648 -0.137966
#
#               Won   century
# runs     0.188319  0.751176
# NotOut   0.214461  0.336174
# bf       0.153881  0.696394
# fours    0.225120  0.591924
# sixes    0.063837  0.547777
# ...

# %%
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
df_mpg=sns.load_dataset('mpg')
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.heatmap(df_mpg.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix
# ...

# %%
rides = pd.read_csv('https://raw.githubusercontent.com/shinokada/python-for-ib-diploma-mathematics/master/Data/OD_2019-05.csv')

# %%
by_end_station = (
    rides
        .loc[:, ['end_station_code', 'duration_sec']]
        .groupby('end_station_code')
        .sum()
        .assign(n_rides=rides['end_station_code'].value_counts())
)
print(by_end_station.head())
# Out:
#                   duration_sec  n_rides
# end_station_code
# 4000                   1498612     1754
# 4001                    181712      152
# 4002                    884874      894
# 5002                    195657      144
# 5003                     95648       83

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

sns.jointplot(x='n_rides', y='duration_sec', data=by_end_station)
plt.show()

# %%
from scipy.stats import rankdata
sns.jointplot(x=rankdata(by_end_station['n_rides']), y=rankdata(by_end_station['duration_sec']))
plt.show()

# %%
pearsonr(by_end_station['n_rides'],by_end_station['duration_sec'])
# Out:
# (0.9334810928766709, 4.504838917124294e-272)

# %%
spearmanr(by_end_station['n_rides'],by_end_station['duration_sec'])
# Out:
# SpearmanrResult(correlation=0.9648807530213751, pvalue=0.0)

# %%
sns.heatmap(df_mpg.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_mpg.corr(method="spearman"),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df_mpg)

# %% [markdown]
# # Poisson Distribution

# %%
from scipy.stats import poisson,binom

# %%
import math
def cal_poisson(k,mu):
    return ((mu**k)*(math.exp(-1*mu))/math.factorial(k))

# %%
cal_poisson(5,3)
# Out:
# 0.10081881344492448

# %%
poisson.pmf(k=5,mu=3)
# Out:
# 0.10081881344492458

# %%
poisson.cdf(k=3,mu=3)
# Out:
# 0.6472318887822313

# %%
poisson.pmf(k=0,mu=3)+poisson.pmf(k=1,mu=3)+poisson.pmf(k=2,mu=3)+poisson.pmf(k=3,mu=3)
# Out:
# 0.6472318887822313

# %%
poisson.pmf(k=0,mu=3)
# Out:
# 0.049787068367863944

# %%
mu = 3

x_values = np.arange(0, 10)
y_values = poisson.pmf(x_values, mu=mu)
sns.barplot(x=x_values, y=y_values)
# Out:
# <AxesSubplot:>

# %%
poisson.cdf(k=1,mu=3)
# Out:
# 0.1991482734714558

# %%
poisson.pmf(k=0,mu=3)+poisson.pmf(k=1,mu=3)
# Out:
# 0.1991482734714558

# %%
poisson.pmf(k=15,mu=18.5)
# Out:
# 0.07188336510431341

# %%
1-poisson.cdf(k=6,mu=18.5)
# Out:
# 0.9992622541111789

# %%
poisson.pmf(k=1,mu=2)
# Out:
# 0.2706705664732254

# %%
poisson.pmf(k=0,mu=1)
# Out:
# 0.36787944117144233

# %%
poisson.pmf(k=3,mu=1.33333333333)
# Out:
# 0.10413714098355689

# %%
poisson.cdf(k=1,mu=0.15)
# Out:
# 0.9898141728888165

# %%
poisson.pmf(k=3,mu=1.2)
# Out:
# 0.08674393303071422

# %%
binom.pmf(n=80,k=3,p=0.015)
# Out:
# 0.08660120920447566

# %% [markdown]
# # Exponential Distribution

# %%
from scipy.stats import expon

# %%
mu = 3

x_values = np.arange(0, 10)
y_values = poisson.pmf(x_values, mu=mu)
sns.barplot(x=x_values, y=y_values)
# Out:
# <AxesSubplot:>

# %%
mu = 6

x_values = np.arange(0, 10)
y_values = poisson.pmf(x_values, mu=mu)
sns.barplot(x=x_values, y=y_values)
# Out:
# <AxesSubplot:>

# %%
poisson.pmf(k=0,mu=10/15)
# Out:
# 0.513417119032592

# %%
1-expon.cdf(x=10,scale=15)
# Out:
# 0.513417119032592

# %%
expon.cdf(x=5,scale=5)-expon.cdf(x=4,scale=5)
# Out:
# 0.08144952294577923

# %%
1-expon.cdf(x=6,scale=5)
# Out:
# 0.3011942119122022

# %%
(1-expon.cdf(x=9,scale=5))/(1-expon.cdf(x=3,scale=5))
# Out:
# 0.3011942119122021

# %%
(1-expon.cdf(x=18,scale=5))/(1-expon.cdf(x=12,scale=5))
# Out:
# 0.3011942119122019

# %%
(1-expon.cdf(x=6,scale=5))
# Out:
# 0.3011942119122022

# %%
(1-expon.cdf(x=5,scale=5))
# Out:
# 0.36787944117144233

# %%
(1-expon.cdf(x=10,scale=5))/(1-expon.cdf(x=5,scale=5))
# Out:
# 0.36787944117144233

# %%
(1-expon.cdf(x=15,scale=5))/(1-expon.cdf(x=10,scale=5))
# Out:
# 0.36787944117144233

# %%
(1-expon.cdf(x=20,scale=5))/(1-expon.cdf(x=15,scale=5))
# Out:
# 0.36787944117144306

# %%
(1-expon.cdf(x=30,scale=(60/3.5)))
# Out:
# 0.17377394345044517

# %% [markdown]
# # Log Normal Distribution

# %%
df=pd.read_csv("waiting_time.csv")
df
# Out:
#              time
# 0      184.003075
# 1       36.721521
# 2       29.970417
# 3       75.640285
# 4       61.489439
# ...           ...
# 90041  135.885984
# 90042   15.223970
# 90043  207.839528
# 90044  140.488418
# 90045   50.719544
#
# [90046 rows x 1 columns]

# %%
sns.histplot(df["time"])
# Out:
# <AxesSubplot:xlabel='time', ylabel='Count'>

# %%
df2=np.log(df)
df2
# Out:
#            time
# 0      5.214952
# 1      3.603363
# 2      3.400211
# 3      4.325989
# 4      4.118865
# ...         ...
# 90041  4.911816
# 90042  2.722871
# 90043  5.336766
# 90044  4.945125
# 90045  3.926311
#
# [90046 rows x 1 columns]

# %%
sns.histplot(df2["time"])
# Out:
# <AxesSubplot:xlabel='time', ylabel='Count'>

# %%
df1=pd.read_csv("aerofit.csv")
df1
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
sns.kdeplot(df1["Income"])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %%
x=10
y=100
z=1000
q=10000

# %%
print("log(x) :",np.log(x))
print("log(y) :",np.log(y))
print("log(z) :",np.log(z))
print("log(q) :",np.log(q))
# Out:
# log(x) : 2.302585092994046
# log(y) : 4.605170185988092
# log(z) : 6.907755278982137
# log(q) : 9.210340371976184

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Task: Determine the eligibility for granting a Home Loan
# Objective of this notebook is:
#
# 1.   To understand the patterns in the data.
# 2.   How to Handle the categorical features.
# 3. How to deal with missing data.
# 4. Feature Engineering
# 5. Finding the most important features while taking the decision of granting a loan application.
# 6. Understanding the Normalization and standardisation of the data.

# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_1samp,ttest_ind,chi2_contingency,shapiro
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import kstest,norm

# %%
df = pd.read_csv('loan.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# # Basic Exploration

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df["Dependents"].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
cat_cols=df.dtypes=="object"
cat_cols=list(cat_cols[cat_cols].index)
cat_cols
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
cat_cols.remove("Loan_Status")

# %%
cat_cols
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area']

# %% [markdown]
# # Univariate Analysis

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# Target Variable
"Loan_Status"
# Out:
# 'Loan_Status'

# %%
sns.countplot(data=df,x="Loan_Status")
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
"ApplicantIncome"
# Out:
# 'ApplicantIncome'

# %%
sns.histplot(data=df,x="ApplicantIncome",kde=True)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Count'>

# %%
sns.boxplot(data=df,x="ApplicantIncome")
# Out:
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
sns.histplot(x=np.log(df["ApplicantIncome"]),kde=True)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Count'>

# %%
qqplot(np.log(df["ApplicantIncome"]),line="s")
plt.show()

# %%
shapiro(np.log(df["ApplicantIncome"]))
# Out:
# ShapiroResult(statistic=0.9351667165756226, pvalue=1.1202605768083568e-15)

# %%
# Ho : The distribution is Gaussian
# Ha : The distribution is NOT Gaussian
log_appl_income=np.log(df["ApplicantIncome"])

z_lai=(log_appl_income-log_appl_income.mean())/log_appl_income.std()

kstest(z_lai,norm.cdf)
# Out:
# KstestResult(statistic=0.08360472600316537, pvalue=0.0003504196051879888)

# %%
sns.boxplot(data=df,y="ApplicantIncome",x="Education")
# Out:
# <AxesSubplot:xlabel='Education', ylabel='ApplicantIncome'>

# %%
plt.figure(figsize=(12,12))
sns.histplot(data=df,x="ApplicantIncome",hue="Education")
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.boxplot(data=df,y="ApplicantIncome",x="Education")
plt.show()

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.groupby(["Loan_Status"]).mean()
# Out:
#              ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_Status
# N                5446.078125        1877.807292  151.220994        344.064516
# Y                5384.068720        1504.516398  144.294404        341.072464
#
#              Credit_History
# Loan_Status
# N                  0.541899
# Y                  0.981818

# %%
df_acc=df[df["Loan_Status"]=="Y"]["ApplicantIncome"]
df_rej=df[df["Loan_Status"]=="N"]["ApplicantIncome"]

# %%
df_acc.mean()
# Out:
# 5384.068720379147

# %%
df_rej.mean()
# Out:
# 5446.078125

# %%
ttest_ind(df_acc,df_rej,alternative='greater')
# Out:
# Ttest_indResult(statistic=-0.11650844828724542, pvalue=0.5463560939347409)

# %%
ttest_ind(df_acc,df_rej,alternative='less')
# Out:
# Ttest_indResult(statistic=-0.11650844828724542, pvalue=0.453643906065259)

# %%
sns.kdeplot(df_acc)
sns.kdeplot(df_rej)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Density'>

# %%
kstest(df_acc,df_rej)
# Out:
# KstestResult(statistic=0.04393759873617693, pvalue=0.9480203334325084)

# %% [markdown]
# # Binning the income

# %%
bins=[0, 2500, 4000, 6000, 8000, 10000, 81000]
labels=['Low','Average','medium', 'h1', 'h2', 'Very high']
df["Incom_bins"]=pd.cut(df["ApplicantIncome"],bins=bins,labels=labels)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
pd.crosstab(df["Incom_bins"],df["Loan_Status"])
# Out:
# Loan_Status   N    Y
# Incom_bins
# Low          34   74
# Average      67  159
# medium       45   98
# h1           20   34
# h2            9   22
# Very high    17   35

# %%
# Ho : Variable are independant
# Ha : Variable are dependant

chi2_contingency(pd.crosstab(df["Incom_bins"],df["Loan_Status"]))
# Out:
# (1.2390175474316056,
#  0.941079844721327,
#  5,
#  array([[ 33.77198697,  74.22801303],
#         [ 70.67100977, 155.32899023],
#         [ 44.71661238,  98.28338762],
#         [ 16.88599349,  37.11400651],
#         [  9.69381107,  21.30618893],
#         [ 16.26058632,  35.73941368]]))

# %%
Income_bin = pd.crosstab(df["Incom_bins"],df["Loan_Status"])

Income_bin.div(Income_bin.sum(axis=1),axis=0).plot(kind="bar",figsize=(4,4))
plt.xlabel("ApplicantIncome")
plt.ylabel("Percentage")
plt.show()

# %%
df["total_household_income"]=df["ApplicantIncome"]+df["CoapplicantIncome"]
df["total_household_income"]
# Out:
# 0      5849.0
# 1      6091.0
# 2      3000.0
# 3      4941.0
# 4      6000.0
#         ...
# 609    2900.0
# 610    4106.0
# 611    8312.0
# 612    7583.0
# 613    4583.0
# Name: total_household_income, Length: 614, dtype: float64

# %%
df_acc1=df[df["Loan_Status"]=="Y"]["total_household_income"]
df_rej1=df[df["Loan_Status"]=="N"]["total_household_income"]

# %%
df_acc1.mean()
# Out:
# 6888.585118456492

# %%
df_rej1.mean()
# Out:
# 7323.885416666667

# %%
ttest_ind(df_acc1,df_rej1,alternative="less")
# Out:
# Ttest_indResult(statistic=-0.773974858431208, pvalue=0.2196222669617997)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'Incom_bins', 'total_household_income'],
#       dtype='object')

# %%
df["EMI"]=(df["LoanAmount"]*1000)/df["Loan_Amount_Term"]
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["ability_to_pay_EMI"]=((df["total_household_income"]*.15)>df["EMI"]).astype("int")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["ability_to_pay_EMI"].mean()
# Out:
# 0.9087947882736156

# %%
sns.countplot(data=df,x="ability_to_pay_EMI",hue="Loan_Status")
# Out:
# <AxesSubplot:xlabel='ability_to_pay_EMI', ylabel='count'>

# %%
va1=pd.crosstab(df["ability_to_pay_EMI"],df["Loan_Status"])
va1
# Out:
# Loan_Status           N    Y
# ability_to_pay_EMI
# 0                    25   31
# 1                   167  391

# %%
chi2_contingency(va1)
# Out:
# (4.465288201035702,
#  0.03459025395658005,
#  1,
#  array([[ 17.51140065,  38.48859935],
#         [174.48859935, 383.51140065]]))

# %%
df["ability_to_pay_EMI_10"]=((df["total_household_income"]*.1)>df["EMI"]).astype("int")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["ability_to_pay_EMI_10"].mean()
# Out:
# 0.8501628664495114

# %%
sns.countplot(data=df,x="ability_to_pay_EMI_10",hue="Loan_Status")
# Out:
# <AxesSubplot:xlabel='ability_to_pay_EMI_10', ylabel='count'>

# %%
va1=pd.crosstab(df["ability_to_pay_EMI_10"],df["Loan_Status"])
va1
# Out:
# Loan_Status              N    Y
# ability_to_pay_EMI_10
# 0                       44   48
# 1                      148  374

# %%
chi2_contingency(va1)
# Out:
# (12.909621328812786,
#  0.0003268974206671644,
#  1,
#  array([[ 28.76872964,  63.23127036],
#         [163.23127036, 358.76872964]]))

# %% [markdown]
# # Credit History vs Loan Status

# %%
va2=pd.crosstab(df["Credit_History"],df["Loan_Status"])
va2
# Out:
# Loan_Status      N    Y
# Credit_History
# 0.0             82    7
# 1.0             97  378

# %%
sns.countplot(data=df,x="Credit_History",hue="Loan_Status")
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %%
chi2_contingency(va2)
# Out:
# (174.63729658142535,
#  7.184759548750746e-40,
#  1,
#  array([[ 28.2464539,  60.7535461],
#         [150.7535461, 324.2464539]]))

# %% [markdown]
# # Missing Data

# %%
((df.isna().sum()/df.shape[0])*100).sort_values(ascending=False)
# Out:
# Credit_History            8.143322
# EMI                       5.863192
# Self_Employed             5.211726
# LoanAmount                3.583062
# Dependents                2.442997
# Loan_Amount_Term          2.280130
# Gender                    2.117264
# Married                   0.488599
# Loan_Status               0.000000
# ability_to_pay_EMI        0.000000
# total_household_income    0.000000
# Incom_bins                0.000000
# Loan_ID                   0.000000
# Property_Area             0.000000
# CoapplicantIncome         0.000000
# ApplicantIncome           0.000000
# Education                 0.000000
# ability_to_pay_EMI_10     0.000000
# dtype: float64

# %%
# df.isna().mean()*100

# %%
df["Credit_History"].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df["Credit_History"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df["Credit_History"].fillna(2,inplace=True)

# %%
df["Credit_History"].unique()
# Out:
# array([1., 0., 2.])

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'Incom_bins', 'total_household_income', 'EMI', 'ability_to_pay_EMI',
#        'ability_to_pay_EMI_10'],
#       dtype='object')

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Self_Employed"].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
df["Self_Employed"]=df["Self_Employed"].fillna("Other")
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes', 'Other'], dtype=object)

# %%
df["Self_Employed"].value_counts()
# Out:
# No       500
# Yes       82
# Other     32
# Name: Self_Employed, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
a = pd.DataFrame([10, 10, 20, 10, 30, 10, np.nan, 50])
a
# Out:
#       0
# 0  10.0
# 1  10.0
# 2  20.0
# 3  10.0
# 4  30.0
# 5  10.0
# 6   NaN
# 7  50.0

# %%
a.mean()
# Out:
# 0    20.0
# dtype: float64

# %%
SimpleImputer(strategy='mean').fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [20.],
#        [50.]])

# %%
SimpleImputer(strategy='median').fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [10.],
#        [50.]])

# %%
SimpleImputer(strategy='most_frequent').fit_transform(a)
# Out:
# array([[10.],
#        [10.],
#        [20.],
#        [10.],
#        [30.],
#        [10.],
#        [10.],
#        [50.]])

# %%
SimpleImputer(strategy='constant',fill_value=100).fit_transform(a)
# Out:
# array([[ 10.],
#        [ 10.],
#        [ 20.],
#        [ 10.],
#        [ 30.],
#        [ 10.],
#        [100.],
#        [ 50.]])

# %%
num_missing=["EMI","LoanAmount","Loan_Amount_Term"]

# %%
median_imputer = SimpleImputer(strategy="median")
mean_imputer = SimpleImputer(strategy="mean")
mode_imputer = SimpleImputer(strategy="most_frequent")
constant_imputer = SimpleImputer(strategy="constant",fill_value=100)

# %%
for col in num_missing:
    df[col]=pd.DataFrame(mean_imputer.fit_transform(pd.DataFrame(df[col])))

# %%
df.isna().sum()
# Out:
# Loan_ID                    0
# Gender                    13
# Married                    3
# Dependents                15
# Education                  0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Property_Area              0
# Loan_Status                0
# Incom_bins                 0
# total_household_income     0
# EMI                        0
# ability_to_pay_EMI         0
# ability_to_pay_EMI_10      0
# dtype: int64

# %%
cat_missing=["Gender","Married","Dependents"]

# %%
mode_imputer = SimpleImputer(strategy="most_frequent")

# %%
for col in cat_missing:
    df[col]=pd.DataFrame(mode_imputer.fit_transform(pd.DataFrame(df[col])))

# %%
df.isna().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status               0
# Incom_bins                0
# total_household_income    0
# EMI                       0
# ability_to_pay_EMI        0
# ability_to_pay_EMI_10     0
# dtype: int64
